# %%
#Description
# write microbial parameters

# %%
microbe_pars={
    'DCKI':'Inhibition of decomposition by respiration-based microbial activity [gC m-3 h-1]:2.5',
    'RCCX':'Maximum fraction of N recycled for microbial reserve [-]:0.833',
    'RCCQ':'Maximum fraction of P recycled for microbial reserve [-]:0.833',
    'RCCZ':'Minimum fraction of senescenced C recycled for microbial reserve [-]:0.167',
    'RCCY':'Maximum fraction of senescenced C recycled for microbial reserve [-]:0.833',
    'FPRIM':'Rate for DOM, microbial activity transfer via priming [h-1]:5.e-2',
    'FPRIMM':'Rate for microbial C,N,P transferred via priming [h-1]:1.e-6',
    'OMGR':'Rate constant for transferring microbial C from nonstructural to structural components [h-1]:2.5e-1',
    'H2KI':'H2 product inhibition for methanogenesis [gH m-3]:1.0',
    'OQKI':'DOC product inhibition constant for decomposition [gC m-3]:1.2E+03',
    'COMKI':'Km to slow microbial decomposition with low microbial C [g micr C (g subs C)-1]:1.e-3',
    'COMKM':'Km to slow microbial maintenance respiration with low microbial C [g micr C (g subs C)-1]:1.e-4',
    'CKC':'Half saturating reserve C concentration for microbial C remobilization [gC (gC)-1]:1.e-3',
    'FOSCZ0':'Surface litter mixing rate [h-1]:2.e-2',
    'FOSCZL':'Subsurface litter mixing rate [h-1]:2.e-6',
    'DCKM0':'Reference Km for litter layer SOC decomposition [gC (g soil)-1]:1.e3',
    'DCKML':'Reference Km for subsurface SOC decomposition [gC (g soil)-1]:1.e3',
    'VMXO':'Specific DOC/acetate oxidation rates for aerobic microbe at 25oC [gC (gC h)-1]:0.125',
    'VMXF':'Specific DOC/acetate oxidation rates for fermentation at 25oC [gC (gC h)-1]:0.125',
    'VMXCH4gAcet':'Specific acetate oxidation rates for acetoclastic methanogens [gC (gC h)-1]:0.125', 
    'VMXNO2Oxi':'Specific NO2 oxidation rate by nitrite oxidizers, [gN (gC)-1 h-1]:0.25', 
    'VMXNH3Oxi':'Specific NH3 oxidation rate by ammonia oxidizers at 25oC [gN (gC h)-1]:0.375',
    'VMXCH4OxiAero':'Specific CH4 oxidation rate by aerobic methanotrophs at 25oC [g (gC h)-1]:0.375',
    'VMXCH4gH2':'Referece specific H2 oxidation rates by hydrogenotrophic methanogens at 25oC [g g-1C h-1]:0.125',
    'OQKM':'Km for DOC uptake by heterotrophic bacteria and fungi [gC m-3]:12',
    'OQKA':'Km for acetate uptake by heterotrophic fermenters, [gC m-3]:12',
    'OQKAM':'Km for acetate uptake by acetoclastic methanogens,[g C m-3]:12',
    'CCKM':'Km for autotrophic CO2 uptake [gC m-3]:0.15',
    'CCK4':'Km for CH4 uptake by aerobic methanotroph [g C m-3]:1.2e-3',
    'ZHKM':'Km for NH4 uptake by ammonia oxidizing nitrifiers [gN m-3]:1.4',
    'ZNKM':'Km for NO2 uptake by nitrite oxidizing nitrifiers [gN m-3]:1.4',
    'Z3KM':'Km for NO3 uptake by facultative denitrifiers [gN m-3]:1.4',
    'Z2KM':'Km for NO2 uptake by facultative denitrifiers [gN m-3]:1.4',
    'Z1KM':'Km for N2O uptake by denitrifiers [gN m-3]:1.4e-2',
    'Z4MX':'Maximum NH4 uptake rate by all microbial functional groups for biomass synthesis [gN m-2 h-1]:5.e-3',
    'Z4KU':'Km for NH4 uptake by all microbial functional groups for biomass synthesis [g N m-3]:0.40',
    'Z4MN':'Minimum concentration for NH4 uptake kinetics by all microbial functional groups for biomass synthesis [gN m-3]:0.0125',
    'ZOMX':'Maximum NO3 uptake rate by all microbial functional groups for biomass synthesis [gN m-2 h-1]:5.e-3', 
    'ZOKU':'Km for NO3 uptake kinetics by all microbial functional groups for biomass synthesis [gN m-3]:0.35',
    'ZOMN':'Minimum concentration for NO3 uptake kinetics by all microbial functional groups for biomass synthesis [g N m-3]:0.03',
    'HPMX':'Maximum H2PO4 uptake rate by all microbial functional groups for biomass synthesis [g P m-2 h-1]:1.e-3',
    'HPKU':'Km for H2PO4 uptake kinetics by all microbial functional groups for biomass synthesis [gP m-3]:0.075',
    'HPMN':'Minimum concentration for H2PO4 uptake kinetics by all microbial functional groups [gP m-3]:0.002',
    'ZFKM':'Km for N2 uptake by free-living diazotrophs for N-fixation [g N m-3]:0.14',
    'H2KM':'Km for H2 uptake by hydrogenotrophic methanogens [g H m-3]:0.01',
    'ECNH':'Efficiency of CO2 conversion to biomass by ammonia oxidizers,[gC biomass (gC CO2)-1]:0.30',
    'ECNO':'Efficiency of CO2 conversion to biomass by nitrite oxidizers,[gC biomass (gC CO2)-1]:0.10',
    'ECHO':'Efficiency of CO2 conversion to biomass by methane oxidizers,[gC biomass (gC CH4)-1]:0.75',
    'ECH2':'Efficiency of CO2 conversion to biomass (CH2O) by hydrogenotrophic methanogen,[gC biomass (gC CO2)-1]:0.3',    
    'RNFNI':'Parameter for nitrification inhibition [-]:2.e-4',
    'ZHKI':'Inhibition of nitrification inhibition by NH3 [gN m-3]:7.e3',
    'VMKI':'Product inhibn for NOx reduction by denitrifiers [g N m-3]:0.25',
    'VHKI':'Product inhibn for NH3 oxidation by nitrifiers, [g N m-3]:15.0',
    'VMX2AMONC10':'Maximum specific uptake rate of NO2(-) by AMO NC-10 [h-1]:0.01',
    'VMX3AMO2D':'Maximum specific uptake rate of NO2(-) by AMO ANME-2D [h-1]:0.01',    
    'OXKA':'Km for O2 uptake by nitrifiers [gO m-3]:0.16',
    'EOMC':'Energy requirements for microbial growth of aerobic bacteria [kJ (gC)-1]:25',
    'EOMD':'Energy requirements for microbial growth of denitrifiers, [kJ (gC)-1]:37.5',
    'EOMG':'Energy requirements for microbial growth of fungi, [kJ (gC)-1]:37.5',
    'EOMF':'Energy requirements for microbial growth of fermenters, [kJ (gC)-1]:75.0',
    'EOMH':'Energy requirements for microbial growth of methanogens, [kJ (gC)-1]:25.0',
    'EOMN':'Energy requirements for microbial growth of diazotrophs, [kJ (gC)-1]:75.0',
    'GO2X':'Free energy yields of redox reactions for DOC->CO2, [kJ (gC)-1]:37.5',
    'GH4X':'Free energy yields of redox reactions for CO2->CH4, [kJ (gC)-1]:66.5',
    'GCHX':'Free energy yields of redox reactions for DOC->acetate, [kJ (gC)-1]:4.5',
    'GC4X':'Free energy yields of redox reactions for acetate->CH4, [kJ (gC)-1]:3.0',
    'GCOX':'Free energy yields of redox reactions for CO2->CH4, [kJ (gC)-1]:11.0',
    'GNOX':'Free energy yields of redox reactions for NO3->NO2, NO2->N2O,N2O->N2, [kJ (gN)-1]:10.0',
    'GN2X':'Free energy yields of redox reactions for N2->NH3, [kJ (gN)-1]:187.5',
    'GN3CX':'Free energy yields of redox reaction for NO3-CH4 => NO2+CO2 [kJ gC-1]:43.08',
    'GN2CX':'Free energy yields of redox reaction for NO2-CH4 => N2+CO2 [kJ gC-1]:77',    
    'TSORP':'Sorption rate constant for OHC [h-1]:0.5',
    'HSORP':'Sorption volume coefficient for OHC [-]:1.0',
    'SPOHC':'Specific decomposition rate constant for adsorbed SOC, [g subs. C g-1 micr. C]:0.25',
    'SPOHA':'Specific decomposition rate constant for adsorbed acetate, [g subs. C g-1 micr. C]:0.25',
    'RMOM':'Specific maintenance respiration [gC (gN)-1 h-1]:0.010',
    'nactbioms':'Number of active biomss components [dimension]:2',    
    'SPORC(nactbioms)':'Specific decomposition rate constant microbial residue [gC gN-1 h-1]:7.5,1.5',
    'SPOMC(nactbioms)':'Specific decomposition rate constant microbial biomass [gC gN-1 h-1]:1.e-2,1.e-2',   
    'jcplx':'Number of organic matter complexes [dimension]:5',
    'NHeterMFG':'Number of hetetrotrophic microbial function groups [dimension]:7',
    'jsken':'Number of kinetic components for each solid organic matter [dimension]:4',
    'DOSA(jcplx)':'Rate constant for litter colonization by heterotrophs [h-1]:0.25E-03,0.25,0.25,0.25,0.25',
    'SPOSC(jsken,jcplx)':"Specific decomposition rate constants for the solid organic matter in different complexes [h-1]:7.5,7.5,1.5,0.5,7.5,7.5,1.5,0.5,7.5,7.5,1.5,0.5,0.05,0.0,0.0,0.0,0.05,0.0167,0.0,0.0",
    'FL(nactbioms)':'Fractionall allocation to kinetic and structural microbial biomass [-]:0.55,0.45',
    'NAerobHeterBactGuilds':'Number of guilds of aerobic heterotrophic bacteria [dimension]:1',
    'NFacultativeDenitGuilds':'Number of guilds of facultative denitrifiers [dimension]:1', 
    'NAerobHeterFungGuilds':'Number of guilds of aerobic heterotrophic fungi [dimension]:1',
    'NFermentorGuilds':'Number of fermentors [dimension]:1',
    'NAcetoMethanogGuilds':'Number of acetoclastic methanogens [dimension]:1',
    'NAerobNfixingGuilds':'Number of aerobic nitrogen fixing bacteria [dimension]:1',
    'NAnaerobNfixGuilds':'Number of anaerobic nitrogen fixing bacteria [dimension]:1',
    'NAmmoniaOxidGuilds':'Number of aerobic ammonia oxidizing bacteria [dimension]:1',
    'NNitriteOxidGuilds':'Number of aerobic nitrite oxidizing bacteria [dimension]:1',
    'NAerobMethnotrophGuilds':'Number of aerobic methanotrophs [dimension]:1',
    'NH2genoMethnogGuilds':'Number of hydrogenotrophic methanogens [dimension]:1',
    'NANME2DArcheaGuilds':'Number of guilds of ANME-2d archaea that use NO3(-)/NO2(-) as electron acceptors and CH4 as C source[dimension]:1',
    'NNC10GroupBacteGuilds':'Number of guilds of NC10 group bacteria that use NO2(-) as electron acceptor and CO2 as C source [dimension]:1', 
    'rNCOMC_AHB(nactbioms,NAerobHeterBactGuilds)':'NC mass ratio of aerobic heterotrophic bacteria [gN gC-1]:0.15,0.09',
    'rPCOMC_AHB(nactbioms,NAerobHeterBactGuilds)':'PC mass ratio of aerobic heterotrophic bacteria [gP gC-1]:0.015,0.009'    
}

# %%
for key,val_str in  microbe_pars.items():    
    parts = val_str.rsplit(':', 1)
    description_with_units = parts[0]
    vals=parts[1].strip()
    
    if '(' in key:
        val=vals.rsplit(',')
        ndim=len(val)
    else:
        val=vals
        ndim=1
    parts=description_with_units.rsplit('[',1)
    description = parts[0].strip()
    unit = parts[1].rstrip(']').strip()
    print('var=%s,long_name=%s,unit=%s,val=%s,ndim=%d'%(key,description,unit,val,ndim))
# Out:
# var=DCKI,long_name=Inhibition of decomposition by respiration-based microbial activity,unit=gC m-3 h-1,val=2.5,ndim=1
# var=RCCX,long_name=Maximum fraction of N recycled for microbial reserve,unit=-,val=0.833,ndim=1
# var=RCCQ,long_name=Maximum fraction of P recycled for microbial reserve,unit=-,val=0.833,ndim=1
# var=RCCZ,long_name=Minimum fraction of senescenced C recycled for microbial reserve,unit=-,val=0.167,ndim=1
# var=RCCY,long_name=Maximum fraction of senescenced C recycled for microbial reserve,unit=-,val=0.833,ndim=1
# var=FPRIM,long_name=Rate for DOM, microbial activity transfer via priming,unit=h-1,val=5.e-2,ndim=1
# var=FPRIMM,long_name=Rate for microbial C,N,P transferred via priming,unit=h-1,val=1.e-6,ndim=1
# var=OMGR,long_name=Rate constant for transferring microbial C from nonstructural to structural components,unit=h-1,val=2.5e-1,ndim=1
# var=H2KI,long_name=H2 product inhibition for methanogenesis,unit=gH m-3,val=1.0,ndim=1
# ...

# %%
import numpy as np
from netCDF4 import Dataset
from datetime import datetime

current_dateTime = datetime.now()
nc_f='../input_data/MicrobePars.%4d%02d%02d.nc'%(current_dateTime.year,current_dateTime.month,current_dateTime.day)

nc_fid = Dataset(nc_f, 'w')

nc_fid.description='Microbial parameters created on %4d/%02d/%02d/%02d:%02d:%02d'% \
(current_dateTime.year,current_dateTime.month,current_dateTime.day, \
 current_dateTime.hour,current_dateTime.minute,current_dateTime.second)

for key,val_str in  microbe_pars.items():    
    parts = val_str.rsplit(':', 1)
    description_with_units = parts[0]
    vals=parts[1].strip()
    if ',' in vals:
        val=vals.rsplit(',')
        ndim=len(val)
    else:
        val=vals
        ndim=1         
    parts=description_with_units.rsplit('[',1)
    description = parts[0].strip()
    unit = parts[1].rstrip(']').strip()
    if unit=='dimension':
        """
        create dimension
        """
        nc_fid.createDimension(key, int(val))        
    else:
        """
        create variable
        """
        if '(' in key:            
            """array"""
            parts=key.split('(')            
            dimstr = parts[1].rstrip(')')
            if ',' in dimstr:
                dims=dimstr.split(',')
            else:
                dims=dimstr
            print(f'{parts[0]} {dims}')
            w_nc_var = nc_fid.createVariable(parts[0], 'f4',(dims))
            w_nc_var.long_name=description
            w_nc_var.units=unit
            arr=[float(item) for item in val]
            if len(dims) > 1:
                target_shape = w_nc_var.shape
                nc_fid.variables[parts[0]][:]=np.reshape(arr,target_shape)
            else:
                nc_fid.variables[parts[0]][:]=arr
        else:
            """scalar"""
            w_nc_var = nc_fid.createVariable(key, 'f4')
            w_nc_var.long_name=description
            w_nc_var.units=unit
            nc_fid.variables[key][:]=float(val)

nc_fid.close()  # close the new file
# Out:
# SPORC nactbioms
# SPOMC nactbioms
# DOSA jcplx
# SPOSC ['jsken', 'jcplx']
# FL nactbioms
# rNCOMC_AHB ['nactbioms', 'NAerobHeterBactGuilds']
# rPCOMC_AHB ['nactbioms', 'NAerobHeterBactGuilds']

# %%
b=[3,[2,3],3]
print(b[0])
print(b[1])
# Out:
# 3
# [2, 3]

# %%
# N2O-relevant parameters and their default values
n2o_params = {
    'Z3KM':  1.4,    # NO3 half-saturation for denitrifiers
    'Z2KM':  1.4,    # NO2 half-saturation for denitrifiers  
    'Z1KM':  0.014,  # N2O half-saturation for denitrifiers
    'EOMD':  37.5,   # energy cost of denitrifier growth
    'GNOX':  10.0,   # free energy of NO3->N2O reaction
    'RMOM':  0.01,   # microbial maintenance respiration
    'VMKI':  0.25,   # NOx product inhibition
    'FOSCZ0': 0.02,  # surface litter mixing rate (carbon input sensitivity)
}

# Show ±20% perturbation ranges
print("Parameter | Default | -20% | +20% | What it controls")
print("-" * 75)
for param, val in n2o_params.items():
    print(f"{param:10s} | {val:7.4f} | {val*0.8:7.4f} | {val*1.2:7.4f} | see above")
# Out:
# Parameter | Default | -20% | +20% | What it controls
# ---------------------------------------------------------------------------
# Z3KM       |  1.4000 |  1.1200 |  1.6800 | see above
# Z2KM       |  1.4000 |  1.1200 |  1.6800 | see above
# Z1KM       |  0.0140 |  0.0112 |  0.0168 | see above
# EOMD       | 37.5000 | 30.0000 | 45.0000 | see above
# GNOX       | 10.0000 |  8.0000 | 12.0000 | see above
# RMOM       |  0.0100 |  0.0080 |  0.0120 | see above
# VMKI       |  0.2500 |  0.2000 |  0.3000 | see above
# FOSCZ0     |  0.0200 |  0.0160 |  0.0240 | see above

# %%
import matplotlib.pyplot as plt
import numpy as np

# How each parameter affects N2O - based on published ecosys sensitivity studies
# Direction: +1 means higher param = more N2O, -1 means higher param = less N2O
params = {
    'Z3KM':  {'default': 1.4,    'direction': -1, 'description': 'NO₃ half-saturation for denitrifiers'},
    'Z1KM':  {'default': 0.014,  'direction': +1, 'description': 'N₂O half-saturation for denitrifiers'},
    'EOMD':  {'default': 37.5,   'direction': -1, 'description': 'Energy cost of denitrifier growth'},
    'GNOX':  {'default': 10.0,   'direction': +1, 'description': 'Free energy of NO₃→N₂O reaction'},
    'RMOM':  {'default': 0.01,   'direction': -1, 'description': 'Microbial maintenance respiration'},
    'VMKI':  {'default': 0.25,   'direction': -1, 'description': 'NOx product inhibition'},
    'FOSCZ0':{'default': 0.02,   'direction': +1, 'description': 'Surface litter mixing (carbon input)'},
}

names = [p for p in params]
directions = [params[p]['direction'] for p in params]
colors = ['tomato' if d > 0 else 'steelblue' for d in directions]
descriptions = [params[p]['description'] for p in params]

fig, ax = plt.subplots(figsize=(9, 5))
bars = ax.barh(names, directions, color=colors)
ax.axvline(0, color='black', linewidth=0.8)
ax.set_xlabel('Effect on N₂O flux  (↑ increases  |  ↓ decreases)')
ax.set_title('EcoSIM parameter sensitivity: direction of effect on N₂O\n(±20% perturbation, based on published ecosys literature)')
for i, (bar, desc) in enumerate(zip(bars, descriptions)):
    ax.text(0.05 if directions[i] > 0 else -0.05, i, desc,
            va='center', ha='left' if directions[i] > 0 else 'right', fontsize=8)
plt.tight_layout()
plt.savefig('n2o_sensitivity_direction.png', dpi=150)
plt.show()
print("Saved: n2o_sensitivity_direction.png")
# Out:
# Saved: n2o_sensitivity_direction.png
